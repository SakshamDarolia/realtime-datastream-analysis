# %%
import requests

from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install confluent-kafka
# Out:
# Collecting confluent-kafka
#   Downloading confluent_kafka-2.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 30.1 MB/s eta 0:00:00
# Installing collected packages: confluent-kafka
# Successfully installed confluent-kafka-2.4.0

# %%
# !pip install confluent-kafka configparser
# Out:
# Requirement already satisfied: confluent-kafka in /usr/local/lib/python3.10/dist-packages (2.4.0)
# Collecting configparser
#   Downloading configparser-7.0.0-py3-none-any.whl (16 kB)
# Installing collected packages: configparser
# Successfully installed configparser-7.0.0

# %%
### For CSV usage

# %%
# Value by value publish

import csv
from confluent_kafka import Producer
import json
import time

# Function to read Confluent Cloud configuration from file
def read_ccloud_config(config_file):
    omitted_fields = set(['schema.registry.url', 'basic.auth.credentials.source', 'basic.auth.user.info'])
    conf = {}
    with open(config_file) as fh:
        for line in fh:
            line = line.strip()
            if len(line) != 0 and line[0] != "#":
                parameter, value = line.strip().split('=', 1)
                if parameter not in omitted_fields:
                    conf[parameter] = value.strip()
    return conf

# Function to publish CSV data to Kafka topic
def publish_csv_to_broker(csv_file):
    # Establish connection to Kafka broker
    producer = Producer(read_ccloud_config("gdrive/My Drive/Colab Notebooks/Big Data/client.properties"))

    # Open the CSV file
    with open(csv_file, newline='') as csvfile:
        reader = csv.DictReader(csvfile)

        # Extract column names from the CSV file
        column_names = reader.fieldnames

        # Iterate over each row in the CSV file
        for row in reader:
            try:
                # Iterate over each column in the row
                for column in column_names:
                    # Define the key and value for Kafka message
                    key = column  # Use column name as the key
                    value = {column: row[column]}  # Use column value as the message content

                    # Serialize the value data to JSON
                    serialized_value = json.dumps(value)

                    # Publish message to Kafka topic
                    producer.produce("topic_0", key=key.encode(), value=serialized_value.encode())

                    print("Published CSV data to Kafka:", key, value)
                    time.sleep(1)  # Optional: Add delay between each message
            except Exception as e:
                print("Error publishing message to Kafka:", e)

    # Flush and close Kafka producer
    producer.flush()
    producer.close()

# Main function to execute the publishing process
def main():
    # CSV file path
    csv_file = "gdrive/My Drive/Colab Notebooks/Big Data/aqi.csv"

    # Publish CSV data to Kafka topic
    publish_csv_to_broker(csv_file)

if __name__ == "__main__":
    main()
# Out:
# Published CSV data to Kafka: Unique ID {'Unique ID': '179772'}
# Published CSV data to Kafka: Indicator ID {'Indicator ID': '640'}
# Published CSV data to Kafka: Name {'Name': 'Boiler Emissions- Total SO2 Emissions'}
# Published CSV data to Kafka: Measure {'Measure': 'Number per km2'}
# Published CSV data to Kafka: Measure Info {'Measure Info': 'number'}
# Published CSV data to Kafka: Geo Type Name {'Geo Type Name': 'UHF42'}
# Published CSV data to Kafka: Geo Join ID {'Geo Join ID': '409'}
# Published CSV data to Kafka: Geo Place Name {'Geo Place Name': 'Southeast Queens'}
# Published CSV data to Kafka: Time Period {'Time Period': '2015'}
# Published CSV data to Kafka: Start_Date {'Start_Date': '01/01/2015'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-618131b2ece3> in <cell line: 65>()
#      64
#      65 if __name__ == "__main__":
# ---> 66     main()
#
# <ipython-input-27-618131b2ece3> in main()
#      61
#      62     # Publish CSV data to Kafka topic
# ---> 63     publish_csv_to_broker(csv_file)
#      64
#      65 if __name__ == "__main__":
#
# <ipython-input-27-618131b2ece3> in publish_csv_to_broker(csv_file)
#      47
#      48                     print("Published CSV data to Kafka:", key, value)
# ---> 49                     time.sleep(1)  # Optional: Add delay between each message
#      50             except Exception as e:
#      51                 print("Error publishing message to Kafka:", e)
#
# KeyboardInterrupt:

# %%
# Row by row publish

import csv
from confluent_kafka import Producer
import json
import time

# Function to read Confluent Cloud configuration from file
def read_ccloud_config(config_file):
    omitted_fields = set(['schema.registry.url', 'basic.auth.credentials.source', 'basic.auth.user.info'])
    conf = {}
    with open(config_file) as fh:
        for line in fh:
            line = line.strip()
            if len(line) != 0 and line[0] != "#":
                parameter, value = line.strip().split('=', 1)
                if parameter not in omitted_fields:
                    conf[parameter] = value.strip()
    return conf

# Function to publish CSV data to Kafka topic
def publish_csv_to_broker(csv_file):
    # Establish connection to Kafka broker
    producer = Producer(read_ccloud_config("gdrive/My Drive/Colab Notebooks/Big Data/client.properties"))

    # Open the CSV file
    with open(csv_file, newline='') as csvfile:
        reader = csv.DictReader(csvfile)

        # Extract column names from the CSV file
        column_names = reader.fieldnames

        record_counter = 1  # Initialize counter for records

        # Iterate over each row in the CSV file
        for row in reader:
            try:
                # Define the key and value for Kafka message
                key = str(record_counter)  # Use record counter as the key
                record_counter += 1  # Increment the counter for the next record

                # Construct the value containing all columns
                value = {column: row[column] for column in column_names}

                # Serialize the value data to JSON
                serialized_value = json.dumps(value)

                # Publish message to Kafka topic
                producer.produce("topic_0", key=key.encode(), value=serialized_value.encode())

                print("Published CSV data to Kafka:", key, value)
                time.sleep(1)  # Optional: Add delay between each message
            except Exception as e:
                print("Error publishing message to Kafka:", e)

    # Flush and close Kafka producer
    producer.flush()
    producer.close()

# Main function to execute the publishing process
def main():
    # CSV file path
    csv_file = "gdrive/My Drive/Colab Notebooks/Big Data/aqi.csv"

    # Publish CSV data to Kafka topic
    publish_csv_to_broker(csv_file)

if __name__ == "__main__":
    main()
# Out:
# Published CSV data to Kafka: 1 {'Unique ID': '179772', 'Indicator ID': '640', 'Name': 'Boiler Emissions- Total SO2 Emissions', 'Measure': 'Number per km2', 'Measure Info': 'number', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': '2015', 'Start_Date': '01/01/2015', 'Data Value': '0.3', 'Message': ''}
# Published CSV data to Kafka: 2 {'Unique ID': '179785', 'Indicator ID': '640', 'Name': 'Boiler Emissions- Total SO2 Emissions', 'Measure': 'Number per km2', 'Measure Info': 'number', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': '2015', 'Start_Date': '01/01/2015', 'Data Value': '1.2', 'Message': ''}
# Published CSV data to Kafka: 3 {'Unique ID': '178540', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Annual Average 2012', 'Start_Date': '12/01/2011', 'Data Value': '8.6', 'Message': ''}
# Published CSV data to Kafka: 4 {'Unique ID': '178561', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Annual Average 2012', 'Start_Date': '12/01/2011', 'Data Value': '8', 'Message': ''}
# Published CSV data to Kafka: 5 {'Unique ID': '823217', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Summer 2022', 'Start_Date': '06/01/2022', 'Data Value': '6.1', 'Message': ''}
# Published CSV data to Kafka: 6 {'Unique ID': '177910', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Summer 2012', 'Start_Date': '06/01/2012', 'Data Value': '10', 'Message': ''}
# Published CSV data to Kafka: 7 {'Unique ID': '177952', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Summer 2013', 'Start_Date': '06/01/2013', 'Data Value': '9.8', 'Message': ''}
# Published CSV data to Kafka: 8 {'Unique ID': '177973', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Summer 2013', 'Start_Date': '06/01/2013', 'Data Value': '9.8', 'Message': ''}
# Published CSV data to Kafka: 9 {'Unique ID': '177931', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Summer 2012', 'Start_Date': '06/01/2012', 'Data Value': '9.6', 'Message': ''}
# Published CSV data to Kafka: 10 {'Unique ID': '742274', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Summer 2021', 'Start_Date': '06/01/2021', 'Data Value': '7.2', 'Message': ''}
# Published CSV data to Kafka: 11 {'Unique ID': '178582', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Annual Average 2013', 'Start_Date': '12/01/2012', 'Data Value': '8.2', 'Message': ''}
# Published CSV data to Kafka: 12 {'Unique ID': '178583', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '210', 'Geo Place Name': 'Coney Island - Sheepshead Bay', 'Time Period': 'Annual Average 2013', 'Start_Date': '12/01/2012', 'Data Value': '8.1', 'Message': ''}
# Published CSV data to Kafka: 13 {'Unique ID': '547477', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Annual Average 2017', 'Start_Date': '01/01/2017', 'Data Value': '6.8', 'Message': ''}
# Published CSV data to Kafka: 14 {'Unique ID': '547417', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '210', 'Geo Place Name': 'Coney Island - Sheepshead Bay', 'Time Period': 'Annual Average 2017', 'Start_Date': '01/01/2017', 'Data Value': '6.8', 'Message': ''}
# Published CSV data to Kafka: 15 {'Unique ID': '177784', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Summer 2009', 'Start_Date': '06/01/2009', 'Data Value': '10.6', 'Message': ''}
# Published CSV data to Kafka: 16 {'Unique ID': '547414', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Annual Average 2017', 'Start_Date': '01/01/2017', 'Data Value': '7.1', 'Message': ''}
# Published CSV data to Kafka: 17 {'Unique ID': '130413', 'Indicator ID': '640', 'Name': 'Boiler Emissions- Total SO2 Emissions', 'Measure': 'Number per km2', 'Measure Info': 'number', 'Geo Type Name': 'UHF42', 'Geo Join ID': '210', 'Geo Place Name': 'Coney Island - Sheepshead Bay', 'Time Period': '2013', 'Start_Date': '01/01/2013', 'Data Value': '0.9', 'Message': ''}
# Published CSV data to Kafka: 18 {'Unique ID': '130412', 'Indicator ID': '640', 'Name': 'Boiler Emissions- Total SO2 Emissions', 'Measure': 'Number per km2', 'Measure Info': 'number', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': '2013', 'Start_Date': '01/01/2013', 'Data Value': '1.7', 'Message': ''}
# Published CSV data to Kafka: 19 {'Unique ID': '130434', 'Indicator ID': '640', 'Name': 'Boiler Emissions- Total SO2 Emissions', 'Measure': 'Number per km2', 'Measure Info': 'number', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': '2013', 'Start_Date': '01/01/2013', 'Data Value': '0', 'Message': ''}
# Published CSV data to Kafka: 20 {'Unique ID': '410847', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Summer 2016', 'Start_Date': '06/01/2016', 'Data Value': '6.9', 'Message': ''}
# Published CSV data to Kafka: 21 {'Unique ID': '177889', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Summer 2011', 'Start_Date': '06/01/2011', 'Data Value': '10.8', 'Message': ''}
# Published CSV data to Kafka: 22 {'Unique ID': '177932', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Summer 2012', 'Start_Date': '06/01/2012', 'Data Value': '9.4', 'Message': ''}
# Published CSV data to Kafka: 23 {'Unique ID': '410782', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Annual Average 2016', 'Start_Date': '12/31/2015', 'Data Value': '7.1', 'Message': ''}
# Published CSV data to Kafka: 24 {'Unique ID': '177974', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Summer 2013', 'Start_Date': '06/01/2013', 'Data Value': '9.5', 'Message': ''}
# Published CSV data to Kafka: 25 {'Unique ID': '410848', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Annual Average 2016', 'Start_Date': '12/31/2015', 'Data Value': '6', 'Message': ''}
# Published CSV data to Kafka: 26 {'Unique ID': '823218', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Winter 2021-22', 'Start_Date': '12/01/2021', 'Data Value': '6.4', 'Message': ''}
# Published CSV data to Kafka: 27 {'Unique ID': '176692', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Annual Average 2013', 'Start_Date': '12/01/2012', 'Data Value': '18.6', 'Message': ''}
# Published CSV data to Kafka: 28 {'Unique ID': '549806', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '209', 'Geo Place Name': 'Bensonhurst - Bay Ridge', 'Time Period': 'Annual Average 2017', 'Start_Date': '01/01/2017', 'Data Value': '17.7', 'Message': ''}
# Published CSV data to Kafka: 29 {'Unique ID': '175369', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Winter 2010-11', 'Start_Date': '12/01/2010', 'Data Value': '25.7', 'Message': ''}
# Published CSV data to Kafka: 30 {'Unique ID': '175915', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '409', 'Geo Place Name': 'Southeast Queens', 'Time Period': 'Summer 2009', 'Start_Date': '06/01/2009', 'Data Value': '16.1', 'Message': ''}
# Published CSV data to Kafka: 31 {'Unique ID': '549872', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Annual Average 2017', 'Start_Date': '01/01/2017', 'Data Value': '12.7', 'Message': ''}
# Published CSV data to Kafka: 32 {'Unique ID': '741006', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Annual Average 2021', 'Start_Date': '01/01/2021', 'Data Value': '11.4', 'Message': ''}
# Published CSV data to Kafka: 33 {'Unique ID': '175916', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Summer 2009', 'Start_Date': '06/01/2009', 'Data Value': '8.6', 'Message': ''}
# Published CSV data to Kafka: 34 {'Unique ID': '336603', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '410', 'Geo Place Name': 'Rockaways', 'Time Period': 'Winter 2014-15', 'Start_Date': '12/01/2014', 'Data Value': '20.7', 'Message': ''}
# Published CSV data to Kafka: 35 {'Unique ID': '178542', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '211', 'Geo Place Name': 'Williamsburg - Bushwick', 'Time Period': 'Annual Average 2012', 'Start_Date': '12/01/2011', 'Data Value': '9.7', 'Message': ''}
# Published CSV data to Kafka: 36 {'Unique ID': '177912', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '211', 'Geo Place Name': 'Williamsburg - Bushwick', 'Time Period': 'Summer 2012', 'Start_Date': '06/01/2012', 'Data Value': '12.3', 'Message': ''}
# Published CSV data to Kafka: 37 {'Unique ID': '177954', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '211', 'Geo Place Name': 'Williamsburg - Bushwick', 'Time Period': 'Summer 2013', 'Start_Date': '06/01/2013', 'Data Value': '12.2', 'Message': ''}
# Published CSV data to Kafka: 38 {'Unique ID': '334047', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '404', 'Geo Place Name': 'Bayside - Little Neck', 'Time Period': 'Winter 2014-15', 'Start_Date': '12/01/2014', 'Data Value': '8.8', 'Message': ''}
# Published CSV data to Kafka: 39 {'Unique ID': '177772', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '104', 'Geo Place Name': 'Pelham - Throgs Neck', 'Time Period': 'Summer 2009', 'Start_Date': '06/01/2009', 'Data Value': '10.4', 'Message': ''}
# Published CSV data to Kafka: 40 {'Unique ID': '742215', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '211', 'Geo Place Name': 'Williamsburg - Bushwick', 'Time Period': 'Annual Average 2021', 'Start_Date': '01/01/2021', 'Data Value': '7.2', 'Message': ''}
# Published CSV data to Kafka: 41 {'Unique ID': '742257', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '404', 'Geo Place Name': 'Bayside - Little Neck', 'Time Period': 'Annual Average 2021', 'Start_Date': '01/01/2021', 'Data Value': '6.3', 'Message': ''}
# Published CSV data to Kafka: 42 {'Unique ID': '178588', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '304', 'Geo Place Name': 'Upper West Side', 'Time Period': 'Annual Average 2013', 'Start_Date': '12/01/2012', 'Data Value': '10.4', 'Message': ''}
# Published CSV data to Kafka: 43 {'Unique ID': '177244', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '304', 'Geo Place Name': 'Upper West Side', 'Time Period': 'Winter 2010-11', 'Start_Date': '12/01/2010', 'Data Value': '14.4', 'Message': ''}
# Published CSV data to Kafka: 44 {'Unique ID': '410828', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '404', 'Geo Place Name': 'Bayside - Little Neck', 'Time Period': 'Winter 2015-16', 'Start_Date': '12/01/2015', 'Data Value': '7.4', 'Message': ''}
# Published CSV data to Kafka: 45 {'Unique ID': '177856', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '104', 'Geo Place Name': 'Pelham - Throgs Neck', 'Time Period': 'Summer 2011', 'Start_Date': '06/01/2011', 'Data Value': '11.5', 'Message': ''}
# Published CSV data to Kafka: 46 {'Unique ID': '823275', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '211', 'Geo Place Name': 'Williamsburg - Bushwick', 'Time Period': 'Winter 2021-22', 'Start_Date': '12/01/2021', 'Data Value': '7.4', 'Message': ''}
# Published CSV data to Kafka: 47 {'Unique ID': '177916', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '304', 'Geo Place Name': 'Upper West Side', 'Time Period': 'Summer 2012', 'Start_Date': '06/01/2012', 'Data Value': '11.4', 'Message': ''}
# Published CSV data to Kafka: 48 {'Unique ID': '410800', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '304', 'Geo Place Name': 'Upper West Side', 'Time Period': 'Annual Average 2016', 'Start_Date': '12/31/2015', 'Data Value': '8.5', 'Message': ''}
# Published CSV data to Kafka: 49 {'Unique ID': '177958', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '304', 'Geo Place Name': 'Upper West Side', 'Time Period': 'Summer 2013', 'Start_Date': '06/01/2013', 'Data Value': '11.4', 'Message': ''}
# Published CSV data to Kafka: 50 {'Unique ID': '605693', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '204', 'Geo Place Name': 'East New York', 'Time Period': 'Annual Average 2018', 'Start_Date': '01/01/2018', 'Data Value': '7.1', 'Message': ''}
# Published CSV data to Kafka: 51 {'Unique ID': '742193', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '204', 'Geo Place Name': 'East New York', 'Time Period': 'Summer 2021', 'Start_Date': '06/01/2021', 'Data Value': '8.3', 'Message': ''}
# Published CSV data to Kafka: 52 {'Unique ID': '177905', 'Indicator ID': '365', 'Name': 'Fine particles (PM 2.5)', 'Measure': 'Mean', 'Measure Info': 'mcg/m3', 'Geo Type Name': 'UHF42', 'Geo Join ID': '204', 'Geo Place Name': 'East New York', 'Time Period': 'Summer 2012', 'Start_Date': '06/01/2012', 'Data Value': '9.7', 'Message': ''}
# Published CSV data to Kafka: 53 {'Unique ID': '175354', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '304', 'Geo Place Name': 'Upper West Side', 'Time Period': 'Winter 2010-11', 'Start_Date': '12/01/2010', 'Data Value': '33.7', 'Message': ''}
# Published CSV data to Kafka: 54 {'Unique ID': '176698', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '304', 'Geo Place Name': 'Upper West Side', 'Time Period': 'Annual Average 2013', 'Start_Date': '12/01/2012', 'Data Value': '26.5', 'Message': ''}
# Published CSV data to Kafka: 55 {'Unique ID': '175364', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '404', 'Geo Place Name': 'Bayside - Little Neck', 'Time Period': 'Winter 2010-11', 'Start_Date': '12/01/2010', 'Data Value': '26.2', 'Message': ''}
# Published CSV data to Kafka: 56 {'Unique ID': '175896', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '211', 'Geo Place Name': 'Williamsburg - Bushwick', 'Time Period': 'Summer 2009', 'Start_Date': '06/01/2009', 'Data Value': '23.1', 'Message': ''}
# Published CSV data to Kafka: 57 {'Unique ID': '549854', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '404', 'Geo Place Name': 'Bayside - Little Neck', 'Time Period': 'Annual Average 2017', 'Start_Date': '01/01/2017', 'Data Value': '16.6', 'Message': ''}
# Published CSV data to Kafka: 58 {'Unique ID': '740946', 'Indicator ID': '375', 'Name': 'Nitrogen dioxide (NO2)', 'Measure': 'Mean', 'Measure Info': 'ppb', 'Geo Type Name': 'UHF42', 'Geo Join ID': '211', 'Geo Place Name': 'Williamsburg - Bushwick', 'Time Period': 'Annual Average 2021', 'Start_Date': '01/01/2021', 'Data Value': '19', 'Message': ''}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-a97f9da167e3> in <cell line: 68>()
#      67
#      68 if __name__ == "__main__":
# ---> 69     main()
#
# <ipython-input-4-a97f9da167e3> in main()
#      64
#      65     # Publish CSV data to Kafka topic
# ---> 66     publish_csv_to_broker(csv_file)
#      67
#      68 if __name__ == "__main__":
#
# <ipython-input-4-a97f9da167e3> in publish_csv_to_broker(csv_file)
#      50
#      51                 print("Published CSV data to Kafka:", key, value)
# ---> 52                 time.sleep(1)  # Optional: Add delay between each message
#      53             except Exception as e:
#      54                 print("Error publishing message to Kafka:", e)
#
# KeyboardInterrupt:

# %%
### For API usage

# %%
import requests

url = "https://zillow56.p.rapidapi.com/search"

querystring = {"location":"houston, tx"}

headers = {
	"X-RapidAPI-Key": "7d1fbcd4dfmshdd985ba83f69d8ep147922jsn6cf883240518",
	"X-RapidAPI-Host": "zillow56.p.rapidapi.com"
}

response = requests.get(url, headers=headers, params=querystring)

print(response.json())
# Out:
# {'results': [{'bathrooms': 2.0, 'bedrooms': 3.0, 'city': 'Houston', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': 0, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=29.729679107666016,-95.2992935180664&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=KpuJnpCAq5rL4CeQ8PwnPQfyMFk=', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 29.72968, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 1106.0, 'longitude': -95.29929, 'lotAreaUnit': 'sqft', 'lotAreaValue': 5000.688, 'price': 275000.0, 'priceForHDP': 275000.0, 'rentZestimate': 1700, 'shouldHighlight': False, 'state': 'TX', 'streetAddress': '416 Forest Hill Blvd', 'taxAssessedValue': 264445.0, 'timeOnZillow': 28000, 'zestimate': 288900, 'zipcode': '77011', 'zpid': 27745967}, {'bathrooms': 2.0, 'bedrooms': 4.0, 'city': 'Houston', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': 0, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'imgSrc': 'https://maps.googleapis.com/maps/api/staticmap?mobile=false&sensor=true&maptype=satellite&size=575x242&zoom=17&center=29.563636779785156,-95.12445831298828&key=AIzaSyBJsNQO5ZeG-XAbqqWLKwG08fWITSxg33w&signature=WmSvi4nnIQGvsKApsnAMSAcH780=', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 29.563637, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 2138.0, 'longitude': -95.12446, 'lotAreaUnit': 'sqft', 'lotAreaValue': 10798.524, 'price': 324000.0, 'priceForHDP': 324000.0, 'rentZestimate': 2199, 'shouldHighlight': False, 'state': 'TX', 'streetAddress': '16111 Diana Ln', 'taxAssessedValue': 334739.0, 'timeOnZillow': 28000, 'zestimate': 310400, 'zipcode': '77062', 'zpid': 28096685}, {'bathrooms': 3.0, 'bedrooms': 3.0, 'city': 'Houston', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': 0, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/826fa6eab1c91e5b3b380ce3890c582c-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 29.783613, 'listing_sub_type': {'is_FSBA': True}, 'livingArea': 2350.0, 'longitude': -95.40351, 'lotAreaUnit': 'sqft', 'lotAreaValue': 3210.372, 'price': 995000.0, 'priceForHDP': 995000.0, 'rentZestimate': 5531, 'shouldHighlight': False, 'state': 'TX', 'streetAddress': '705 Ashland St', 'taxAssessedValue': 933890.0, 'timeOnZillow': 570000, 'zestimate': 927800, 'zipcode': '77007', 'zpid': 161436234}, {'bathrooms': 3.0, 'bedrooms': 3.0, 'city': 'Houston', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': 0, 'homeStatus': 'FOR_SALE', 'homeStatusForHDP': 'FOR_SALE', 'homeType': 'SINGLE_FAMILY', 'imgSrc': 'https://photos.zillowstatic.com/fp/bd045a19159818b22b6397b1a7539bfd-p_e.jpg', 'isFeatured': False, 'isNonOwnerOccupied': True, 'isPreforeclosureAuction': False, 'isPremierBuilder': False, 'isShowcaseListing': False, 'isUnmappable': False, 'isZillowOwned': False, 'latitude': 29.834307, 'listing_sub_type': {'is_newHome': True}, 'livingArea': 1380.0, 'longitude': -95.30776, 'newConstructionType': 'BUILDER_SPEC', 'price': 242000.0, 'priceForHDP': 242000.0, 'rentZestimate': 1452, 'shouldHighlight': False, 'state': 'TX', 'streetAddress': '8207 Westcott St', 'timeOnZillow': 691000, 'zestimate': 236000, 'zipcode': '77016', 'zpid': 2054236320}, {'bathrooms': 3.0, 'bedrooms': 5.0, 'city': 'Houston', 'country': 'USA', 'currency': 'USD', 'daysOnZillow': 0, 'homeStatus': 'FOR_SALE', 'homeStat ...

# %%
from confluent_kafka import Producer, KafkaException
import time
import json

#config_file = "gdrive/My Drive/Colab Notebooks/Big Data/client.properties"

# Function to read Confluent Cloud configuration from file
def read_ccloud_config():
    omitted_fields = set(['schema.registry.url', 'basic.auth.credentials.source', 'basic.auth.user.info'])
    conf = {}
    with open("client.properties") as fh:
        for line in fh:
            line = line.strip()
            if len(line) != 0 and line[0] != "#":
                parameter, value = line.strip().split('=', 1)
                if parameter not in omitted_fields:
                    conf[parameter] = value.strip()
    return conf

# Function to publish JSON data to Kafka topic
def publish_json_to_broker(response):
    # Establish connection to Kafka broker
    producer = Producer(read_ccloud_config("client.properties"))

    # Parse JSON response
    results = response.get('results', [])

    # Iterate over each record in the response and publish to Kafka topic
    for result in results:
        try:
            payload = json.dumps(result)
            # Publish message to Kafka topic
            producer.produce("topic_0", value=payload.encode())
            print("Published JSON data to Kafka:", payload)
            time.sleep(1)  # Optional: Add delay between each message
        except KafkaException as ke:
            print("Error publishing message to Kafka:", ke)

    # Flush and close Kafka producer
    producer.flush()
    producer.close()

# Main function to execute the publishing process
def main():

    # Continuously publish JSON data to Kafka topic
    while True:
        publish_json_to_broker(response)  # Publish JSON data
        time.sleep(10)  # Optional: Add delay between each iteration

if __name__ == "__main__":
    main()
